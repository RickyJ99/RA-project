# %% [markdown]
# # From Cohmetrix output to csv
# Given as input the folder that contains the Cohmetrix output of our dataset (in this case only for the Trump dataset)
# the program returns a csv that merge the dataset of trump speech and the outcome for each speech in cohmetrix

# %%
import os
import pandas as pd

def import_txt_files_to_dataframe(folder_path):

    # Get a list of all the text files in the folder
    files = []
    for count in range(len(os.listdir(folder_path))-1):
        path = folder_path + "CohMetrixOutput (" + str(count) + ").txt"
        files.append(path)

    # Initialize an empty DataFrame
    df = pd.DataFrame()
    
    # Iterate over each file
    for file in files:
        file_path = os.path.join(folder_path, file)
        
        # Read the text file into a DataFrame
        #/Users/riccardodalcero/Library/CloudStorage/OneDrive-UniversitaCattolicaSacroCuore-ICATT/Materials/RA/Code_From Download to Dataset/Resources/Trump_Full/CohMetrixOutput (0).txt
        data = pd.read_csv(file_path, delimiter='\t', index_col=False)

        #taking only the colum Text and labele
        data = data.iloc[:, [1,3]]

        # Transpose the DataFrame and set row labels as column labels
        data = data.T

        # Reset the column labels to be the first row of the transposed DataFrame
        data.columns =data.iloc[0]

            # Remove the first row, which is now redundant as column labels
        data =data[1:]
                
        # Append the data to the main DataFrame
        df = pd.concat([df, data], ignore_index = True)
    
    return df
def check_duplicates(dataframe):
    # Check for duplicates in the DataFrame
    duplicates = dataframe.duplicated()
    
    if duplicates.any():
        # Get the duplicate rows
        duplicate_rows = dataframe[duplicates]
        print("Duplicate rows:")
        print(duplicate_rows)
    else:
        print("No duplicates found.")

# Provide the folder path containing the text files
folder_path = '/Users/riccardodalcero/Library/CloudStorage/OneDrive-UniversitaCattolicaSacroCuore-ICATT/Materials/RA/Code_From Download to Dataset/Resources/Trump_full/'

# Call the function to import the text files into a DataFrame
df = import_txt_files_to_dataframe(folder_path)

#check duplicates
#check_duplicates(df)
#df[df.duplicated(subset=['DESPC'])] # True
df
# Save the DataFrame as a CSV file
#dataframe.to_csv('output.csv', index=False)
# Out:
# Label DESPC  DESSC   DESWC  DESPL DESPLd   DESSL  DESSLd DESWLsy DESWLsyd
# 0      12.0   17.0   462.0  1.417  0.996  27.412  26.432   1.758    1.036  \
# 1      19.0   33.0   539.0  1.737  1.195  16.455  11.592   1.644    0.928
# 2      17.0   26.0   407.0  1.529  1.125  15.885  11.039   1.779    1.046
# 3      43.0   50.0  2635.0  1.163  0.485   52.78  27.678   1.524    0.901
# 4      14.0   18.0   372.0  1.286  0.825  21.056  16.297   1.608    0.947
# ..      ...    ...     ...    ...    ...     ...     ...     ...      ...
# 328    21.0   69.0  1409.0  3.286  1.901  20.594  11.137   1.686    0.977
# 329    28.0   85.0  1701.0  3.036  1.688  20.071  14.166   1.645    0.937
# 330    22.0   79.0  1295.0  3.591  2.039   16.57  11.149   1.725    1.038
# 331    29.0   99.0  1504.0  3.414  2.428  15.273  11.659   1.653     0.96
# 332    41.0  103.0  2032.0  2.512  1.362  19.835  13.727   1.704    0.971
#
# Label DESWLlt  ...  WRDCNCc  WRDIMGc  WRDMEAc WRDPOLc WRDHYPn WRDHYPv
# 0       5.396  ...  384.217  413.622  433.516   3.506   6.503   1.904  \
# 1       5.072  ...  388.208  417.266  437.788   3.896   5.597   1.947
# 2       5.378  ...   361.56  394.846  426.952    3.13   6.265   1.906
# 3       4.594  ...  369.961  400.047  434.212   4.051    6.04   1.732
# 4       5.062  ...  417.915  455.787  446.029   3.308   4.991   1.733
# ..        ...  ...      ...      ...      ...     ...     ...     ...
# 328     5.107  ...  390.927  426.958  438.841   3.658   6.524   1.867
# 329     4.961  ...  382.124  415.633   430.24   3.772   6.223    1.88
# 330     5.118  ...  383.342  416.485  431.699   3.873   6.062   1.792
# 331     5.016  ...  392.037  425.328  433.157   3.683   5.771    1.78
# 332     5.123  ...  386.936  423.603   432.74   3.436   5.647   1.798
#
# Label WRDHYPnv   RDFRE  RDFKGL    RDL2
# 0          2.3  30.525  15.753    9.31
# 1        2.083  51.175  10.179  12.049
# 2         1.95  40.443  11.507  11.528
# 3        1.662  24.414  22.946  17.321
# 4         2.06  49.821  11.445  17.412
# ..         ...     ...     ...     ...
# 328       2.15  43.473  12.269   9.696
# 329      2.119  47.356  11.626    9.32
# 330      2.028  44.262  11.158   8.768
# 331      2.027  51.571    9.84  10.238
# 332      2.097  42.653  12.211   8.206
#
# [333 rows x 106 columns]

# %%
# Add a new column "Record Order" to the df dataframe representing the order of records using the 68 records that i got
# from cohmetrix (because it does not work!!!)
df['Record Order'] = range(0, 333)

# Read the larger dataset CSV file
df_1 = pd.read_csv("/Users/riccardodalcero/Library/CloudStorage/OneDrive-UniversitaCattolicaSacroCuore-ICATT/Materials/RA/Data/4_Data_with_AI_Market_Indicies.csv", sep=",")

# Convert the "Date Time" column to datetime format
df_1["Date Time"] = pd.to_datetime(df_1["Date Time"], format="%Y-%m-%d %H:%M:%S%z")

# Filter the smaller dataset (trump_2020)
trump_2020 = df_1[ (df_1["Title"].str.contains("Press Bri"))
    & (df_1["Administration"].str.contains("Trump"))
].loc[:, :]

trump_2020 = trump_2020.sort_index() 

trump_2020['Record Order'] = range(0, 333)
# Merge the two datasets using the "Record Order" column as the key
merged_data = pd.merge(trump_2020, df, on = 'Record Order')
merged_data.to_csv("/Users/riccardodalcero/Library/CloudStorage/OneDrive-UniversitaCattolicaSacroCuore-ICATT/Materials/RA/Data/6_TrumpwithCohmetrix.csv", index = False)
